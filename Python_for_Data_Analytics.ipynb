# %% [markdown]
# <a href="https://colab.research.google.com/github/pulkitgpt5/DSA/blob/main/Python_for_Data_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas --upgrade
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 106.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# ...

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
# Pandas is used for Data Manipulation and Analysis
import pandas as pd

# %%
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
list_of_nums=[3,4,5,6,7]

# %%
series=pd.Series(list_of_nums)

# %%
series
# Out:
# 0    3
# 1    4
# 2    5
# 3    6
# 4    7
# dtype: int64

# %%
series[1]
# Out:
# np.int64(4)

# %%
series[0:3]
# Out:
# 0    3
# 1    4
# 2    5
# dtype: int64

# %%
series_of_nums=pd.Series(list_of_nums,index=['a','b','c','d','e'])

# %%
series_of_nums
# Out:
# a    3
# b    4
# c    5
# d    6
# e    7
# dtype: int64

# %%
series_of_nums=pd.Series(list_of_nums,index=[True,False,True,False,True])

# %%
series_of_nums
# Out:
# True     3
# False    4
# True     5
# False    6
# True     7
# dtype: int64

# %%
dataset=pd.RangeIndex(start=0,stop=5,step=1)

# %%
dataset
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
dataset[4]
# Out:
# 4

# %%
# Panadas Dataframe\
pd.DataFrame({'A':[1,2,3,4,5],'B':[6,7,8,9,10]})
# Out:
#    A   B
# 0  1   6
# 1  2   7
# 2  3   8
# 3  4   9
# 4  5  10

# %%
# prompt: find out the dataset location to load the dataset

import pandas as pd
# The provided code snippets do not include a dataset file path.
# To load a dataset, you need to specify the file path.
# Example:
# Assuming your dataset is a CSV file named 'my_dataset.csv' in your current directory:
# dataset_path = 'my_dataset.csv'

# Then load the dataset using pandas:
# df = pd.read_csv(dataset_path)
# print(df.head())


# If your dataset is located elsewhere, provide the correct file path:
# dataset_path = '/path/to/your/dataset.csv'
# df = pd.read_csv(dataset_path)
# print(df.head())

# Replace 'dataset.csv' with your actual file name and adjust the path accordingly.
# Out:
#    A  B
# 0  a  f
# 1  b  g
# 2  c  h
# 3  d  i
# 4  e  j

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([30,45,40],index=["2015","2016","2017"],name='Product A')
# Out:
# 2015    30
# 2016    45
# 2017    40
# Name: Product A, dtype: int64

# %%
dataset=pd.read_csv('/content/winemag-data-130k-v2.csv')

# %%
# how big the dataset i s?
dataset.shape
# Out:
# (64458, 14)

# %%
dataset.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco    87.0    NaN  Sicily & Sardinia
# 1                            Avidagos    87.0   15.0              Douro
# 2                                 NaN    87.0   14.0             Oregon
# 3                Reserve Late Harvest    87.0   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block    87.0   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
dataset=pd.read_csv('/content/winemag-data-130k-v2.csv',index_col=0)

# %%
dataset.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
pd.set_option('display.max_rows',5)

# %%
dataset
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
dataset.country
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
dataset['country']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c12e379e8530> in <cell line: 0>()
# ----> 1 dataset['country']
#
# NameError: name 'dataset' is not defined

# %%
dataset[country][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ea668f28fe25> in <cell line: 0>()
# ----> 1 dataset[country][0]
#
# NameError: name 'dataset' is not defined
